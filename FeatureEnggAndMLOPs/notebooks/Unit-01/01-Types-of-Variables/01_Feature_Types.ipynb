# %% [markdown]
# # Feature Engineering Lab 02
# # Feature Types
#
# ## Learning Objectives
#
# - Identify different feature types
# - Distinguish numerical and categorical variables
# - Understand raw vs derived features
# - Prepare features before model building

# %% [markdown]
# # Why?
#
# A machine learning model cannot understand the meaning of a column.
# It only sees numbers.
#
# Before building a model, we must identify **what type of feature each column is**.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:\\Projects\\PycharmProjects\\GitRepo\\FeatureEnggAndMLOPs\\datasets\\employee_salary.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 df=pd.read_csv("../../../datasets/employee_salary.csv")
#       5 df.head()
#
# File ~\miniconda3\envs\feature-engg-mlops\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ## Manual Exercise
#
# Before running the next cell, classify each column as:
#
# - Numerical Continuous
# - Numerical Discrete
# - Nominal
# - Ordinal
# - Identifier
#
# Write your answers on paper first.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        100 non-null    int64
#  1   Age               100 non-null    int64
#  2   Gender            100 non-null    str
#  3   Department        100 non-null    str
#  4   Education         100 non-null    str
#  5   Experience_Years  100 non-null    int64
#  6   Salary            100 non-null    int64
# dtypes: int64(4), str(3)
# memory usage: 5.6 KB

# %% [markdown]
# ## Feature Classification
#
# | Column | Type |
# |--------|------|
# |EmployeeID|Identifier|
# |Age|Numerical|
# |Gender|Binary Categorical|
# |Department|Nominal|
# |Education|Ordinal|
# |Experience_Years|Numerical|
# |Salary|Target Variable|

# %%
print(df.dtypes)

print("\nUnique Departments")
print(df["Department"].unique())

print("\nUnique Education Levels")
print(df["Education"].unique())
# Out:
# EmployeeID          int64
# Age                 int64
# Gender                str
# Department            str
# Education             str
# Experience_Years    int64
# Salary              int64
# dtype: object
#
# Unique Departments
# <StringArray>
# ['Sales', 'Finance', 'HR', 'IT', 'Marketing']
# Length: 5, dtype: str
#
# Unique Education Levels
# <StringArray>
# ['Bachelor', 'Master', 'High School', 'PhD']
# Length: 4, dtype: str

# %%
df["Department"].value_counts().plot(kind="bar")
plt.title("Employees by Department")
plt.xlabel("Department")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Real-world Discussion
#
# **Raw Feature**
#
# Date of Birth
#
# ↓
#
# **Derived Feature**
#
# Age
#
# A derived feature often carries more useful information for machine learning.

# %% [markdown]
# # Interview Questions
#
# 1. Difference between nominal and ordinal features?
# 2. What is a binary feature?
# 3. Why should EmployeeID not be used for prediction?
# 4. Give two examples of derived features.
#
# # Assignment
#
# 1. Add a new feature:
#
# Experience_Level
#
# - Beginner
# - Intermediate
# - Expert
#
# 2. Identify whether it is nominal or ordinal.
#
# 3. Explain your reasoning.
